# %% [markdown]
# # Remote Job Market Intelligence using Ethical Web Scraping
# Project Type: Data Science Internship Project

# %% [markdown]
# # 1. Project Introduction & Business Context

# %% [markdown]
# Why This Project Matters
# In today's job market, data is everything. Companies, recruiters, and business analysts constantly ask questions like: What skills are most in-demand right now? Which job titles pay the highest? How is the remote work market growing? These questions cannot be answered through guesswork—they require real data collected systematically from job boards.
#
# This project teaches you how to collect that data ethically and legally. Remote OK is one of the largest job boards for remote work positions, with thousands of job postings updated daily. By scraping this data responsibly, you will understand how real companies and data professionals extract market intelligence without breaking laws or harming the platforms they use.

# %% [markdown]
# # Libraries Installation

# %%
pip install requests
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (2.28.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests) (1.26.14)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\siddh\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\siddh\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\siddh\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\siddh\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\siddh\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\siddh\appdata\roaming\python\python310\site-packages)

# %% [markdown]
# Installs the requests library, which is used to send HTTP requests in Python.
# It allows easy interaction with APIs and web services using methods like GET and POST.

# %%
# !pip install beautifulsoup4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: beautifulsoup4 in c:\programdata\anaconda3\lib\site-packages (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in c:\programdata\anaconda3\lib\site-packages (from beautifulsoup4) (2.3.2.post1)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\siddh\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\siddh\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\siddh\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\siddh\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\siddh\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\siddh\appdata\roaming\python\python310\site-packages)

# %% [markdown]
# Installs BeautifulSoup4, a Python library used for parsing and extracting data from HTML/XML documents.
# Commonly used with requests for web scraping and DOM navigation.

# %% [markdown]
# Job Title

# %%
import requests
import time

url = "https://remoteok.com/api"
response = requests.get(url)

data = response.json()
jobs = data[1:]

count = 0
for job in jobs:
    title = job.get("position")
    if title:
        count += 1
        print(f"{count}. {title}")
        time.sleep(1)   

print("\nTotal jobs found:", count)
# Out:
# 1. SQUIRE
# 2. Coding Bootcampï¹£Job Guaranteed
# 3. Executive Assistant Operations Virtual Assistant
# 4. Marketing &amp; Sponsorship Coordinator
# 5. Staff Software Engineer Money
# 6. Senior Cloud Engineer
# 7. Regional Director Public Sector Sales DOW
# 8. Senior Staff AI Software Engineer
# 9. Security Architect
# 10. Member of Technical Staff Fullstack Engineer
# 11. Staff Software Engineer Simulation
# 12. Software Engineer Networking Software and Services
# 13. Client Success Executive Wayforge
# 14. WNS Global Services
# 15. Virtual Operations Manager
# 16. Client Success Manager Coupa
# 17. Social Media Manager Platform
# 18. IT Operations Specialist
# 19. Senior Software Engineer
# 20. Senior Specialist Senior Accountant Shared Financial Services
# 21. Senior Product Manager
# 22. Senior Engineering Manager Infrastructure
# 23. Work From Home Benefits Services Representative
# 24. Senior Infrastructure Engineer
# 25. Senior Software Developer II Cloud
# 26. HR Administrator
# 27. Product Designer
# 28. Client Success Manager
# 29. Full Stack Developer
# 30. Sales Development Manager
# 31. Current job openings
# 32. Senior Business Analyst
# 33. Project Coordinator Contract
# 34. Commercial Sales Engineer Central
# 35. Business Development Manager
# 36. Motion Designer
# 37. Social Media Content Specialist
# 38. Senior Backend Software Engineer
# 39. DevOps Software Engineer Energy Storage
# 40. Business Systems Analyst
# 41. Customer Experience Associate New Req
# 42. Frontend Engineer Trading Platform
# 43. Internal Controls &amp; Policy Adherence Testing Analyst
# 44. Frontend Product Engineer
# 45. Commercial P&amp;C Support Representative
# 46. Content Manager
# 47. Associate Clinical Director Oncology
# 48. Recovery Analyst Underpayments
# 49. Cloud Full Stack Python Software Engineer US
# 50. Customer Care Specialist Inbound Phone Support
# 51. Staff Software Engineer Backend with Close 10 years of experience
# 52. Technical Program Associate
# 53. Full Stack Engineer Contacts
# 54. Product Security Engineer DeFi
# 55. Senior Frontend Engineer
# 56. Site Reliability Engineer
# 57. Product Manager Wallet SDKs
# 58. Growth Marketing Manager
# 59. Senior Data Engineer
# 60. Social Media Manager
# 61. Senior Full Stack Engineer
# 62. Project Director Campus Action Planning
# 63. Member Support Specialist
# 64. Product Manager GeckoTerminal
# 65. Senior Analytics Engineer
# 66. Growth Marketer
# 67. BIM Modeler
# 68. Commercial Pilots AI Trainer
# 69. Senior Director Global Support
# 70. Medical Affairs Writer Contract
# 71. Executive Director Patient Advocacy
# 72. Manager Commercial Sales
# 73. SEC Reporting Manager
# 74. Director Medical Information
# 75. Associate Medical Writer
# 76. Junior Account Manager
# 77. Vice President Commercial & Channel Sales
# 78. Managing Director AMER Advertising Solutions
# 79. SaaS Business Development Representative U.S. Eastern Time Zone
# 80. Web Analyst Web Data and Analytics
# 81. Software Engineer Infrastructure
# 82. Senior Data Engineer
# 83. Performance Application Engineer Intelligent Factory
# 84. Software Manager Exchange
# 85. Staff Software Engineer Backend
# 86. AI Engineer
# 87. Executive Virtual Assistant
# 88. Data Engineer
# 89. Director of Narrative and Video Storytelling
# 90. Senior GenAI Technical Lead Partner Platforms
# 91. Current openings
# 92. Senior DevOps Engineer
# 93. Senior Research Engineer OLMo
# 94. Head of Studio Standards and Business
# 95. Staff User Researcher
# 96. Operations Recruiter
# 97. Full Stack Software Engineer III Angular Java
# 98. JumpCloud
# 99. Marketing Strategist
# 100. Software Engineer
#
# Total jobs found: 100

# %% [markdown]
# This code retrieves job listings from the RemoteOK API and outputs job titles sequentially.
# A 1-second delay (time.sleep(1)) is applied during iteration while counting and displaying the total number of job titles retrieved.

# %% [markdown]
# Company Name

# %%
data = response.json()

jobs = data[1:]

count = 0
for job in jobs:
    company = job.get("company")
    if company:
        count += 1
        print(f"{count}. {company}")
        time.sleep(1)   

print("\nTotal companies found:", count)
# Out:
# 1. SQUIRE
# 2. Metana
# 3. Assist World
# 4. Assist World
# 5. Galileo Financial Technologies
# 6. ClickHouse
# 7. Chainguard
# 8. Aegis Ventures
# 9. Dexterity
# 10. Inflection AI
# 11. Muon Space
# 12. xAI
# 13. SBI Growth
# 14. WNS Global Services
# 15. Women Builders Council
# 16. CrossCountry Consulting
# 17. Digital Media Management
# 18. MyFunded Futures
# 19. Chainguard
# 20. Make-A-Wish America
# 21. Agile Six
# 22. MZLA Technologies Corporation
# 23. Global Elite Texas
# 24. Paradigm Health
# 25. Life360
# 26. Offshore Launch
# 27. Ahrefs
# 28. Offshore Launch
# 29. MicroVentures
# 30. Dune
# 31. Databricks
# 32. Xpansiv
# 33. INFUSE
# 34. Chainguard
# 35. Unlimit
# 36. Alpaca
# 37. AllTrails
# 38. Teleport
# 39. Redwood Materials
# 40. NASA Federal Credit Union
# 41. Koala Health
# 42. MyFunded Futures
# 43. CloudWalk
# 44. Mento
# 45. Thimble
# 46. Terra
# 47. Private Health Management
# 48. Trend Health Partners
# 49. Railroad19, Inc
# 50. HONK
# 51. Outreach
# 52. GiveDirectly
# 53. Calendly
# 54. FalconX
# 55. Arize AI
# 56. Wormhole Foundation
# 57. Startale
# 58. InfStones
# 59. Nansen.ai
# 60. GiveDirectly
# 61. Teleport
# 62. Campus Compact
# 63. DISQO
# 64. CoinGecko
# 65. Alpaca
# 66. BitMEX
# 67. Sanctuary
# 68. Handshake
# 69. Elite Technology
# 70. Kyverna Therapeutics
# 71. Kyverna Therapeutics
# 72. Cribl
# 73. HighLevel
# 74. Kyverna Therapeutics
# 75. Precision AQ
# 76. Unlimited Technology
# 77. DNSFilter
# 78. Kochava
# 79. Buynomics
# 80. Best Egg
# 81. xAI
# 82. HugeInc
# 83. Intrinsic
# 84. GHX
# 85. Leona Health
# 86. Magna Legal Services
# 87. Offshore Launch
# 88. Sayari
# 89. Field AI
# 90. 2100 NVIDIA USA
# 91. Sezzle
# 92. Little Thinking Minds
# 93. The Allen Institute for Artificial Intelligence
# 94. Samsung Research America
# 95. Nourish
# 96. Field AI
# 97. MeridianLink
# 98. JumpCloud
# 99. OneLocal
# 100. Field Nation
#
# Total companies found: 100

# %% [markdown]
# This code fetches job data from the RemoteOK API and outputs company names sequentially.
# A 1-second delay (time.sleep(1)) is applied during iteration while counting and displaying the total number of companies extracted.

# %% [markdown]
# Skills

# %%
data = response.json()

jobs = data[1:]

count = 0
for job in jobs:
    tags = job.get("tags")
    if tags:
        count += 1
        print(f"{count}. {', '.join(tags)}")
        time.sleep(1)   

print("\nTotal jobs with skills:", count)
# Out:
# 1. No Tech Background Needed, Job or 100% Money Back
# 2. assistant, system, consulting, founder, support, bookkeeping, financial, admin, management, operations, executive
# 3. coordinator, support, content, marketing, sales, non tech
# 4. software, finance, financial, banking, excel, analytics, engineer, engineering
# 5. security, architect, c, cloud, senior, engineer
# 6. director, security, software, cloud, management, marketing, sales
# 7. software, python, technical, growth, senior, operational, health, healthcare, engineer, backend
# 8. security, architect, python, full-stack, docker, software, devops, c++, cloud, robotics, git, operations
# 9. technical, support, engineer, engineering, backend, fullstack
# 10. software, design, system, web, cloud, api, operations, engineer, engineering, digital nomad
# 11. software, support, travel, reliability, engineer, engineering
# 12. marketing, consulting, growth, management, executive
# 13. full time, other
# 14. consulting, manager, saas, support, software, growth, travel, accounting, financial, post-production, microsoft, management, lead, operational, excel, sales, health, healthcare
# 15. manager, training, copywriting, growth, video, strategy, exec, management, content, marketing, analytics, health
# 16. security, support, financial, mobile, operations
# 17. software, design, cloud, management, senior, go, engineer, engineering, backend, digital nomad
# 18. accountant, accounting, financial, senior
# 19. manager, growth, senior
# 20. manager, senior, engineering
# 21. security, training, architect, test, growth, financial, video, part-time
# 22. security, devops, cloud, senior, medical, healthcare, engineer, engineering
# 23. developer, software, cloud, php, mobile, senior, operations, go, backend, digital nomad
# 24. hr, growth, payroll, administrator, operations
# 25. design, designer, technical, software, manager, lead, senior, marketing, sales, engineering, recruitment, digital nomad
# 26. manager, support, growth, operations, full-time
# 27. developer, laravel, senior, engineering, digital nomad
# 28. manager, saas, crypto, technical, travel, scheme, strategy, lead, analytics, sales, go, health, engineering, part-time
# 29. analyst, design, system, security, technical, recruiter, support, testing, manager, education, microsoft, management, lead, senior, operational, recruiting, digital nomad
# 30. security, coordinator, test, manager, video, recruiting, non tech
# 31. security, technical, support, serverless, cloud, sales, engineer
# 32. manager, crypto, support, growth, financial, fintech, strategy, recruiting, executive
# 33. design, crypto, designer, technical, ui, web, financial, video, investment, c, api, mobile, digital nomad
# 34. design, support, growth, video, education, investment, content, digital nomad
# 35. software, security, recruiter, code, education, cloud, senior, go, health, engineer, engineering, linux, backend
# 36. software, growth, web, devops, operations, engineer
# 37. analyst, design, system, training, technical, support, software, investment, microsoft, management, junior, operational, part-time, digital nomad
# 38. technical, support, web, voice, medical, health, healthcare
# 39. frontend, design, test, code, financial, api, engineer, backend, digital nomad
# 40. testing, analyst, design, technical, support, test, financial, operations, operational, engineering, digital nomad
# 41. frontend, design, growth, engineer, engineering, digital nomad
# 42. training, technical, support, software, sales, health
# 43. manager, design, writer, support, ux, seo, leader, strategy, lead, content, senior, marketing, health, healthcare, digital nomad
# 44. director, manager, exec, management, lead, go, medical, health, healthcare
# 45. analyst, system, software, microsoft, excel, medical, health, healthcare
# 46. python, software, react, technical, code, serverless, cloud, nosql, angular, health, engineer, engineering, full-time
# 47. support, growth, operations, operational, sales, full-time
# 48. software, design, technical, code, microsoft, senior, sales, engineer, backend, digital nomad
# 49. technical, software, financial, operations
# 50. design, saas, react, front-end, technical, software, growth, web, cloud, node.js, engineer, engineering, backend, digital nomad
# 51. defi, security, design, crypto, cryptocurrency, support, code, financial, finance, management, engineer, engineering, digital nomad
# 52. frontend, react, typescript, api, senior, junior, engineer, engineering, backend
# 53. security, support, operational, reliability, engineer
# 54. manager
# 55. growth, manager, web3, node, mobile, management, marketing, analytics, sales, full-time
# 56. crypto, software, senior, operational, analytics, engineer, engineering
# 57. manager, software, financial, management, operations
# 58. design, security, recruiter, support, code, voice, education, investment, typescript, senior, go, health, engineer, engineering, digital nomad
# 59. director, students, technical, support, growth, education, investment, senior
# 60. support, test, growth, lead, health
# 61. manager, design, crypto, cryptocurrency, support, software, test, growth, voice, financial, education, leader, marketing, digital nomad
# 62. crypto, technical, support, financial, investment, finance, c, api, senior, operations, operational, marketing, analytics, engineer, executive
# 63. growth, crypto, cryptocurrency, security, marketer
# 64. design, system, 3d, consultant, consulting, technical, support, test, management, lead, engineering, digital nomad
# 65. trainer, system, students, test, content, operational, recruiting
# 66. director, saas, embedded, system, support, financial, cloud, leader, management, senior, operations, operational, executive
# 67. writer, management, lead, content
# 68. director, support, education, investor, strategy, lead, senior, recruitment, educational, executive
# 69. manager, security, technical, strategy, lead, operations, excel, sales
# 70. manager, technical, support, accounting, financial, education, investor, api, management, marketing, legal, sales
# 71. director, system, training, support, leader, strategy, management, lead, content, senior, operational, biotech, health, healthcare
# 72. writer, support, education, content, marketing, legal, non tech
# 73. manager, security, support, management, junior, sales, healthcare, non tech
# 74. design, support, growth, manager, lead, marketing, sales, full-time, digital nomad
# 75. director, saas, gaming, technical, growth, finance, ads, mobile, leader, strategy, management, lead, senior, marketing, sales, executive
# 76. saas, system, support, growth, lead, sales
# 77. web, analyst, technical, testing, growth, director, financial, strategy, management, lead, marketing, analytics, health
# 78. software, engineer, engineering
# 79. support, senior, engineer, engineering
# 80. system, technical, software, testing, test, c++, robotics, strategy, lead, reliability, engineer
# 81. software, manager, technical, java, lambda, angular, management, lead
# 82. software, python, cto, technical, strategy, medical, health, engineer, engineering, backend
# 83. support, legal, engineer
# 84. assistant, founder, ceo, support, growth, operations, executive, full-time
# 85. python, software, code, financial, investment, scala, engineer, engineering
# 86. director, technical, support, software, web, video, robotics, leader, lead, content, sales, go, executive
# 87. design, technical, support, software, growth, cloud, leader, strategy, lead, senior, engineering, digital nomad
# 88. security, students, architect, technical, support, devops, cloud, lead, senior, junior, operational, engineer
# 89. senior, excel, engineer, engineering
# 90. security, technical, testing, test, video, strategy, junior
# 91. mobile, health, healthcare, non tech
# 92. design, technical, recruiter, support, software, financial, finance, robotics, management, senior, operations, analytics, sales, go, recruiting, executive, digital nomad
# 93. software, design, front-end, back-end, full-stack, technical, support, testing, ui, code, web, devops, java, angular, lead, senior, junior, engineer, digital nomad
# 94. saas, consult, technical, strategist, seo, management, content, marketing, analytics, branding
# 95. software, saas, react, docker, technical, support, growth, web, php, html, git, mysql, node.js, mobile, engineer, engineering, linux
# Total jobs with skills: 95

# %% [markdown]
# This code retrieves job listings from the RemoteOK API and prints the skills/tags for each job one by one.
# A 1-second delay (time.sleep(1)) is applied during iteration while counting the jobs that contain skill information.

# %% [markdown]
# Locations

# %%
data = response.json()

jobs = data[1:]

count = 0
for job in jobs:
    location = job.get("location")
    if location:
        count += 1
        print(f"{count}. {location}")
        time.sleep(1)   

print("\nTotal jobs with location:", count)
# Out:
# 1. Remote
# 2. New York City
# 3. United States
# 4. Washington DC
# 5. Remote, U.S.
# 6. Redwood City
# 7. Palo Alto
# 8. San Jose
# 9. Remote
# 10. Remote
# 11. India
# 12. United States
# 13. United States
# 14. Remote
# 15. Remote
# 16. Remote
# 17. United States
# 18. Remote Canada
# 19. Portland, Maine
# 20. Remote - United States
# 21. Remote, Canada
# 22. Remote
# 23. Remote
# 24. Remote
# 25. Texas
# 26. London
# 27. Remote
# 28. Remote
# 29. Remote
# 30. United States
# 31. Remote - North America
# 32. Remote
# 33. United States
# 34. San Francisco
# 35. Remote
# 36. Remote
# 37. Remote
# 38. United States
# 39. Remote
# 40. United States
# 41. U.S.
# 42. Remote
# 43. Remote
# 44. U.S. Remote
# 45. Remote
# 46. Hyderabad
# 47. London
# 48. Remote - US
# 49. New York City
# 50. Remote
# 51. Remote
# 52. Remote
# 53. Texas
# 54. Remote EMEA, Remote Asia
# 55. Nairobi
# 56. United States
# 57. Remote - Anywhere in the U.S.
# 58. Yerevan
# 59. Malaysia
# 60. Remote - North America
# 61. Remote - Europe
# 62. New Delhi
# 63. San Francisco
# 64. US - Remote
# 65. Remote
# 66. Remote
# 67. Remote - United States
# 68. United States
# 69. Remote
# 70. Remote, United States
# 71. Remote
# 72. Remote
# 73. United States
# 74. Eastern Time Zone (EST) USA
# 75. Remote / Flexible
# 76. Palo Alto
# 77. United States
# 78. Mountain View
# 79. Louisville
# 80. San Francisco
# 81. Remote
# 82. Remote
# 83. Remote - US
# 84. Irvine, CA
# 85. US, CA, Santa Clara
# 86. Remote
# 87. Amman
# 88. Seattle, WA
# 89. Irvine
# 90. New York
# 91. Irvine, CA
# 92. Remote
# 93. Dhaka
#
# Total jobs with location: 93

# %% [markdown]
# This code fetches job listings from the RemoteOK API and outputs job locations sequentially.
# A 1-second delay (time.sleep(1)) is applied after each iteration while counting and displaying jobs with location data.

# %% [markdown]
# Job Type

# %%
count = 0

job_type_keywords = [
    "full-time", "contract", "part-time", "freelance", "internship"
]

for job in jobs:
    tags = job.get("tags", [])
    job_types = [tag for tag in tags if tag.lower() in job_type_keywords]

    if job_types:
        count += 1
        print(f"{count}. {', '.join(job_types)}")
        time.sleep(1)   

print("\nTotal jobs with job type:", count)
# Out:
# 1. part-time
# 2. full-time
# 3. part-time
# 4. part-time
# 5. full-time
# 6. full-time
# 7. full-time
# 8. full-time
# 9. full-time
#
# Total jobs with job type: 9

# %% [markdown]
# This code identifies job types by matching predefined employment keywords within each job’s tags and prints them one by one.
# A 1-second pause using time.sleep(1) is added after each iteration to apply rate limiting.

# %% [markdown]
# Date Posted

# %%
import requests
from datetime import datetime

url = "https://remoteok.com/api"
response = requests.get(url)
data = response.json()

jobs = data[1:] 

count = 0
for job in jobs:
    epoch_time = job.get("epoch")  
    if epoch_time:
        count += 1
        date_posted = datetime.fromtimestamp(epoch_time)
        print(f"{count}. Date Posted: {date_posted}")

print("\nTotal jobs with date:", count)
# Out:
# 1. Date Posted: 2026-01-02 21:30:21
# 2. Date Posted: 2026-01-02 14:36:50
# 3. Date Posted: 2026-01-02 10:30:08
# 4. Date Posted: 2026-01-02 10:30:01
# 5. Date Posted: 2026-01-02 03:30:55
# 6. Date Posted: 2026-01-02 03:30:37
# 7. Date Posted: 2026-01-02 03:30:17
# 8. Date Posted: 2026-01-02 02:30:15
# 9. Date Posted: 2026-01-01 03:30:02
# 10. Date Posted: 2025-12-31 13:30:42
# 11. Date Posted: 2025-12-31 13:30:18
# 12. Date Posted: 2025-12-30 20:30:10
# 13. Date Posted: 2025-12-30 17:30:16
# 14. Date Posted: 2025-12-30 13:30:29
# 15. Date Posted: 2025-12-30 10:03:06
# 16. Date Posted: 2025-12-30 05:31:40
# 17. Date Posted: 2025-12-30 05:31:33
# 18. Date Posted: 2025-12-30 05:31:27
# 19. Date Posted: 2025-12-30 05:31:11
# 20. Date Posted: 2025-12-30 05:30:49
# 21. Date Posted: 2025-12-30 05:30:27
# 22. Date Posted: 2025-12-30 01:30:42
# 23. Date Posted: 2025-12-29 23:30:55
# 24. Date Posted: 2025-12-29 23:30:31
# 25. Date Posted: 2025-12-29 23:30:14
# 26. Date Posted: 2025-12-29 21:31:31
# 27. Date Posted: 2025-12-29 21:31:02
# 83. Job URL:https://remoteOK.com/remote-jobs/remote-performance-application-engineer-intelligent-factory-intrinsic-1129307
# 84. Job URL:https://remoteOK.com/remote-jobs/remote-software-manager-exchange-ghx-1129306
# 85. Job URL:https://remoteOK.com/remote-jobs/remote-staff-software-engineer-backend-leona-health-1129305
# 86. Job URL:https://remoteOK.com/remote-jobs/remote-ai-engineer-magna-legal-services-1129304
# 87. Job URL:https://remoteOK.com/remote-jobs/remote-executive-virtual-assistant-offshore-launch-1129303
# 88. Job URL:https://remoteOK.com/remote-jobs/remote-data-engineer-sayari-1129302
# 89. Job URL:https://remoteOK.com/remote-jobs/remote-director-of-narrative-and-video-storytelling-field-ai-1129301
# 90. Job URL:https://remoteOK.com/remote-jobs/remote-senior-genai-technical-lead-partner-platforms-2100-nvidia-usa-1129300
# 91. Job URL:https://remoteOK.com/remote-jobs/remote-current-openings-sezzle-1129297
# 92. Job URL:https://remoteOK.com/remote-jobs/remote-senior-devops-engineer-little-thinking-minds-1129296
# 93. Job URL:https://remoteOK.com/remote-jobs/remote-senior-research-engineer-olmo-the-allen-institute-for-artificial-intelligence-1129294
# 94. Job URL:https://remoteOK.com/remote-jobs/remote-head-of-studio-standards-and-business-samsung-research-america-1129293
# 95. Job URL:https://remoteOK.com/remote-jobs/remote-staff-user-researcher-nourish-1129292
# 96. Job URL:https://remoteOK.com/remote-jobs/remote-operations-recruiter-field-ai-1129291
# 97. Job URL:https://remoteOK.com/remote-jobs/remote-full-stack-software-engineer-iii-angular-java-meridianlink-1129290
# 98. Job URL:https://remoteOK.com/remote-jobs/remote-jumpcloud-jumpcloud-1129289
# 99. Job URL:https://remoteOK.com/remote-jobs/remote-marketing-strategist-onelocal-1129288
# 100. Job URL:https://remoteOK.com/remote-jobs/remote-software-engineer-field-nation-1129287
#
# Total job URLs found: 100

# %% [markdown]
# This code retrieves the unique job URL associated with each job listing to ensure data traceability and direct access to the original posting. Since the API provides URLs in relative format, the base RemoteOK domain is appended to generate complete, clickable links. Each job URL is printed individually, allowing further inspection or downstream scraping of detailed job information.

# %% [markdown]
#  Pagination and Multi-Page Scraping

# %%
import requests
import time
import pandas as pd

url = "https://remoteok.com/api"

headers = {
    "User-Agent": "Mozilla/5.0",
    "Accept": "application/json"
}

all_jobs = []

response = requests.get(url, headers=headers)
response.raise_for_status()

data = response.json()
jobs = data[1:]  

for job in jobs:
    job_url = job.get("url")
    if job_url and job_url.startswith("/"):
        job_url = "https://remoteok.com" + job_url

    job_data = {
        "Job Title": job.get("position"),
        "Company Name": job.get("company"),
        "Job Tags / Skills": job.get("tags"),
        "Location": job.get("location"),
        "Job Type": job.get("type"),
        "Date Posted": pd.to_datetime(job.get("epoch"), unit="s"),
        "Job URL": job_url
    }

    all_jobs.append(job_data)
    time.sleep(1)

df = pd.DataFrame(all_jobs)
print("Total jobs scraped:", len(df))
# Out:
# Total jobs scraped: 100

# %% [markdown]
# This code fetches job listings from the RemoteOK API, extracts key job details such as title, company, skills, location, job type, posting date, and URL, and stores them in a Pandas DataFrame. A short delay is added between iterations to apply rate limiting and ensure safe data collection.
